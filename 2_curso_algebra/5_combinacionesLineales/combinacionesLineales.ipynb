# %%
import sys

sys.path.append("../4_graficarVectores")

from graficarVectores import graficarVectores

# %% [markdown]
# metodo del paralelogramo (combinacion lineal de dos vectores)

# %%
import numpy as np
import matplotlib.pyplot as plt

vecA = np.array([1, 2])
vecB = np.array([1, -2])
graficarVectores([vecA, vecB, 2*vecA+3*vecB])

# %% [markdown]
# la suma de los 2 vectores con todas las posibles variables a y b puede definir el espacio

# %%
for a in range(-10, 10):
    for b in range(-10, 10):
        plt.scatter(vecA[0]*a + vecB[0]*b, vecA[1]*a + vecB[1]*b)
        marker = '.'
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')
plt.show()

# %%
from mlp_toolkits.mplot3d import axes3D

vecA = np.array([1, 2, 0])
vecB = np.array([1, -2, 0])

fig = plt.figure()
ax = fig.add_subplot(111, proyection='3d'

    for b in range(-10, 10):
        plt.scatter(vecA[0]*a + vecB[0]*b, vecA[1]*a + vecB[1]*b, vecA, vecA[2]*a + vecB[2]*b)
        marker = '.'

plt.show()
