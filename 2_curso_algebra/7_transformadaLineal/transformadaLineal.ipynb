# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import sys
sys.path.append('../0_herramientas/')
from graficarVectores import graficarVectores

# %%
# hagamos la matriz de rotacion por ejemplo
A = np.array([[np.cos(np.pi), -np.sin(np.pi)], [np.sin(np.pi), np.cos(np.pi)]])
A
# Out:
# array([[-1.0000000e+00, -1.2246468e-16],
#        [ 1.2246468e-16, -1.0000000e+00]])

# %%
vector = np.array([1, 2])
vector
# Out:
# array([1, 2])

# %%
graficarVectores([vector], colores = ['blue'])

# %%
# hagamos la trsformacion lineal del vector respecto a la matriz a
vector_transformado = A.dot(vector)
graficarVectores([vector, vector_transformado], colores = ['blue', 'pink'])
